# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import warnings
warnings.filterwarnings("ignore")

# %%
pip install mlxtend
# Out:
# Collecting mlxtend
#   Downloading mlxtend-0.23.3-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\91912\anaconda3\lib\site-packages (from mlxtend) (1.12.0)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\91912\anaconda3\lib\site-packages (from mlxtend) (1.26.4)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\91912\anaconda3\lib\site-packages (from mlxtend) (2.2.2)
# Requirement already satisfied: scikit-learn>=1.3.1 in c:\users\91912\anaconda3\lib\site-packages (from mlxtend) (1.4.2)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\91912\anaconda3\lib\site-packages (from mlxtend) (3.8.4)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\91912\anaconda3\lib\site-packages (from mlxtend) (1.4.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\91912\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\91912\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\91912\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\91912\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\91912\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\91912\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\91912\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\91912\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\91912\anaconda3\lib\site-packages (from pandas>=0.24.2->mlxtend) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\91912\anaconda3\lib\site-packages (from pandas>=0.24.2->mlxtend) (2023.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\91912\anaconda3\lib\site-packages (from scikit-learn>=1.3.1->mlxtend) (2.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\91912\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)
# Downloading mlxtend-0.23.3-py3-none-any.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    -------- ------------------------------- 0.3/1.4 MB 5.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.0/1.4 MB 8.8 MB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 9.5 MB/s eta 0:00:00
# Installing collected packages: mlxtend
# Successfully installed mlxtend-0.23.3
# Note: you may need to restart the kernel to use updated packages.

# %%
# randomly generate a classification dataset

# %%
from sklearn.datasets import make_classification

# %%
fv,cv = make_classification(n_samples = 1000,
                    n_features = 2,
                    n_informative = 2,
                    n_redundant = 0,
                    n_repeated = 0,
                    n_classes = 2,
                    n_clusters_per_class = 2,
                    weights = [0.5,0.5],
                    class_sep = 1.0,
                    random_state = 1)

# %%
fv.shape
# Out:
# (1000, 2)

# %%
cv.shape
# Out:
# (1000,)

# %%
sns.scatterplot(x = fv[:,0],y = fv[:,1],hue = cv)
plt.show()

# %%
from sklearn.model_selection import train_test_split,cross_validate,cross_val_score

# %%
x_train,x_test,y_train,y_test = train_test_split(fv,cv,test_size = 0.2,stratify = cv)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors = 1)

cross_val_score(estimator = knn,X=x_train,y = y_train,cv = 3,scoring = "accuracy").mean() # But giving only cv accuracy but we need train accuracy also so we cross_vaidate
# Out:
# 0.8349994837280468

# %%
d = cross_validate(estimator = knn,X = x_train,y = y_train,cv = 3,scoring = "accuracy",return_train_score=True)

# %%
d
# Out:
# {'fit_time': array([0., 0., 0.]),
#  'score_time': array([0.01568317, 0.03115606, 0.01563573]),
#  'test_score': array([0.83146067, 0.83895131, 0.83458647]),
#  'train_score': array([1., 1., 1.])}

# %%
train_error = []
cv_error = []
for k in range(1,100,2):
    knn = KNeighborsClassifier(n_neighbors = k)
    cv_error.append(1- cross_validate(estimator = knn,X = x_train,y = y_train,cv = 3,scoring = "accuracy",return_train_score=True)["test_score"].mean())
    train_error.append(1-cross_validate(estimator = knn,X = x_train,y = y_train,cv = 3,scoring = "accuracy",return_train_score=True)["train_score"].mean())

# %%
plt.plot(range(1,100,2),train_error,label = "train_error")
plt.plot(range(1,100,2),cv_error,label = "cv_error")
plt.legend()
plt.show()

# %%
knn = KNeighborsClassifier(n_neighbors = 90)

# %%
model = knn.fit(x_train,y_train)

# %%
y_cap = model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_cap)
# Out:
# 0.855

# %% [markdown]
# ### Decision Surface

# %%
knn = KNeighborsClassifier(n_neighbors = 1)
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %%
import mlxtend

# %%
from mlxtend.plotting import plot_decision_regions

# %%
knn = KNeighborsClassifier(n_neighbors = 1)
knn.fit(x_train,y_train)
plot_decision_regions(X = x_train,y = y_train,clf = knn)
# Out:
# <Axes: >

# %%
knn = KNeighborsClassifier(n_neighbors = 5)
knn.fit(x_train,y_train)
plot_decision_regions(X = x_train,y = y_train,clf = knn)
# Out:
# <Axes: >

# %%
knn = KNeighborsClassifier(n_neighbors = 20)
knn.fit(x_train,y_train)
plot_decision_regions(X = x_train,y = y_train,clf = knn)
# Out:
# <Axes: >
